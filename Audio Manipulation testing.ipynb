# %%
import librosa
import librosa.display
import numpy, scipy, matplotlib.pyplot as plt, IPython.display as ipd
import ffmpeg

# %%
t, s = librosa.load('./clips/test.wav', duration=5.0)
print(sr)

ipd.Audio(t, rate = s*1.2)
# Out:
# 22050
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
x1, sr1 = librosa.load('clips/Song2.mp3', duration = 20)
ipd.Audio(x1, rate = sr1)

# %%
tempo = librosa.beat.tempo(x, sr=sr)
print(tempo)
tempo = librosa.beat.tempo(x1, sr = sr1)
print(tempo)
# Out:
# [99.38401442]
# [123.046875]

# %%
from scipy.io import wavfile

# %%
wavfile.write('clips/test.wav', int(sr / 1.25), x1)
x2, sr = librosa.load('clips/test.wav', duration = 15)
tempo = librosa.beat.tempo(x2, sr = sr)
print(tempo)
print(sr)
ipd.Audio(x2, rate = sr)
# Out:
# [99.38401442]
# 22050
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
from pydub import AudioSegment
from pydub.playback import play
# Out:
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pydub/utils.py:170: RuntimeWarning: Couldn't find ffmpeg or avconv - defaulting to ffmpeg, but may not work
#   warn("Couldn't find ffmpeg or avconv - defaulting to ffmpeg, but may not work", RuntimeWarning)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pydub/utils.py:184: RuntimeWarning: Couldn't find ffplay or avplay - defaulting to ffplay, but may not work
#   warn("Couldn't find ffplay or avplay - defaulting to ffplay, but may not work", RuntimeWarning)

# %%
import urllib.request
# Download an audio file

# %%
loop = AudioSegment.from_mp3("./clips/Song.mp3")
# Play the result

# %%
length = len(loop)

fade_time = 10000
fade = loop.fade_in(fade_time).fade_out(fade_time)
print(fade_time)

# %%
loop2 = AudioSegment.from_mp3('./clips/Song2.mp3')

loop3 = loop.reverse().pan(-1).overlay(loop.pan(1))

# %%
loop4 = loop.append(loop2, crossfade = 30000)
